# %%
# %%time
import numpy as np                 # for numerical computing
import pandas as pd                # for dataframe and manipulation
import seaborn as sns              #for graphs and data visualization
from matplotlib import pyplot as plt
sns.set()
# %matplotlib inline
# Out:
# CPU times: total: 0 ns
# Wall time: 822 μs

# %%
df = pd.read_csv("C:\\Users\\KINTA\\Downloads\\netflix_shows_movies.csv")

# %%
df.shape
# Out:
# (6234, 12)

# %%
df.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.head(5)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
categorical = df.dtypes[df.dtypes == "object"].index
print(categorical)

df[categorical].describe()
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added', 'rating',
#        'duration', 'listed_in', 'description'],
#       dtype='object')
#          type title                director                cast  \
# count    6234  6234                    4265                5664
# unique      2  6172                    3301                5469
# top     Movie  Love  Raúl Campos, Jan Suter  David Attenborough
# freq     4265     3                      18                  18
#
#               country       date_added rating  duration      listed_in  \
# count            5758             6223   6224      6234           6234
# unique            554             1524     14       201            461
# top     United States  January 1, 2020  TV-MA  1 Season  Documentaries
# freq             2032              122   2027      1321            299
#
#                                               description
# count                                                6234
# ...

# %%
df.tail()
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
# delete unnecessary variables
del df["cast"]

# %%
# delete unnecessary variables
del df["director"]

# %%
# delete unnecessary variables
del df["date_added"]

# %%
# delete unnecessary variables
del df["show_id"]

# %%
# delete unnecessary variables
del df["description"]

# %%
df.dtypes
# Out:
# type            object
# title           object
# country         object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
# to shows where the null values is present
df.isnull()
# Out:
#        type  title  country  release_year  rating  duration  listed_in
# 0     False  False    False         False   False     False      False
# 1     False  False    False         False   False     False      False
# 2     False  False    False         False   False     False      False
# 3     False  False    False         False   False     False      False
# 4     False  False    False         False   False     False      False
# ...     ...    ...      ...           ...     ...       ...        ...
# 6229  False  False    False         False   False     False      False
# 6230  False  False    False         False   False     False      False
# 6231  False  False     True         False    True     False      False
# 6232  False  False    False         False   False     False      False
# 6233  False  False    False         False   False     False      False
#
# [6234 rows x 7 columns]

# %%
# to shows the count of null values
df.isnull() .sum()
# Out:
# type              0
# title             0
# country         476
# release_year      0
# rating           10
# duration          0
# listed_in         0
# dtype: int64

# %%
df.fillna({'country':'missing','rating':'missing'},inplace=True)

# %%
# to re-check the count of null values
df.isnull() .sum()
# Out:
# type            0
# title           0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        type   title country  release_year rating duration  \
# 2124  Movie  Sarkar   India          2018  TV-MA  162 min
#
#                                              listed_in
# 2124  Action & Adventure, Dramas, International Movies

# %%
df.drop([2124], inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [type, title, country, release_year, rating, duration, listed_in]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (6233, 7)

# %%
# visualization on most watch genre
gg = tem_df['listed_in'].str.split(', ', expand=True)

# %%
# visualization on most watch genre
print(gg.isnull().sum())
# Out:
# 0       0
# 1    1072
# 2    2614
# dtype: int64

# %%
# visualization on most watch genre
gg_counts = gg.stack().value_counts()
gg_counts
# Out:
# International Movies        1926
# Dramas                      1622
# Comedies                    1113
# Documentaries                668
# Action & Adventure           596
# Independent Movies           552
# Thrillers                    392
# Children & Family Movies     378
# Romantic Movies              376
# Stand-Up Comedy              281
# Horror Movies                262
# Music & Musicals             243
# Sci-Fi & Fantasy             193
# Sports Movies                157
# Classic Movies                84
# LGBTQ Movies                  60
# Movies                        56
# Cult Movies                   55
# Faith & Spirituality          47
# Anime Features                45
# Name: count, dtype: int64

# %%
# visualization on most watch genre
gg_counts.plot.barh(title='Movies Category', color='pink')
plt.show()

# %%
# visualization on rating distribution
tem_df['rating'].value_counts()
# Out:
# rating
# TV-MA       1347
# TV-14       1038
# R            506
# TV-PG        432
# PG-13        286
# NR           202
# PG           183
# TV-G          80
# TV-Y7         69
# TV-Y          41
# G             36
# TV-Y7-FV      27
# missing        8
# UR             7
# NC-17          2
# Name: count, dtype: int64

# %%
# visualization on rating distribution
tem_df['rating'].value_counts().plot.bar()
plt.show()

# %%
# statistics analysis
all_index_of_season = df[df['duration'].str.contains('Season')].index.to_list()
tem_df = df.drop(all_index_of_season).reset_index(drop=True)
tem_df['duration'] = tem_df['duration'].str.split(' ').str.get(0).astype(int)

# %%
# statistics analysis
tem_df['duration'].describe()
# Out:
# count    4264.000000
# mean       99.086069
# std        28.061615
# min         3.000000
# 25%        86.000000
# 50%        98.000000
# 75%       115.000000
# max       312.000000
# Name: duration, dtype: float64

# %%
# statistics analysis
sns.histplot(data=tem_df, x='duration', kde=True)
plt.show()
